# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %%
cd gdrive/MyDrive/UFV/2020-4 (PER)/TCC_Victor/
# Out:
# /content/gdrive/MyDrive/UFV/2020-4 (PER)/TCC_Victor

# %%
! ls
# Out:
# classificacao_originais_semPCA.py    dataset	     kfold.py
# classificacao_segmentadas.py	     eff	     resnet
# classificacao_segmentadas_semPCA.py  execucao.ipynb  segmentadas

# %%
! python classificacao_segmentadas_semPCA.py
